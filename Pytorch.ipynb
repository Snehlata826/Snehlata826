# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehlata826/Snehlata826/blob/main/Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
data = [[1,2],[3,4]]
x_data = torch.tensor(data)

# %%
x_data
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
# tensor from numpy array
np_array = np.array(data)
x_np = torch.from_numpy(np_array)

# %%
x_np
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
# !pip install torchgeo
# Out:
# Requirement already satisfied: torchgeo in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.8.0)
# Requirement already satisfied: fiona>=1.8.21 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.9.6)
# Requirement already satisfied: kornia>=0.7.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.7.3)
# Requirement already satisfied: lightly!=1.4.26,>=1.4.5 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.5.12)
# Requirement already satisfied: lightning!=2.3.*,>=2 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.4.0)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (3.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.26.4)
# Requirement already satisfied: pandas>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.1.4)
# Requirement already satisfied: pillow>=8.4 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (9.4.0)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (3.6.1)
# Requirement already satisfied: rasterio>=1.3 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.3.10)
# Requirement already satisfied: rtree>=1 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.3.0)
# Requirement already satisfied: segmentation-models-pytorch>=0.2 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.3.4)
# Requirement already satisfied: shapely>=1.8 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.0.6)
# Requirement already satisfied: timm>=0.4.12 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.9.7)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (2.4.0+cu121)
# Requirement already satisfied: torchmetrics>=0.10 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (1.4.1)
# Requirement already satisfied: torchvision>=0.14 in /usr/local/lib/python3.10/dist-packages (from torchgeo) (0.19.0+cu121)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (2024.7.4)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->torchgeo) (1.16.0)
# Requirement already satisfied: kornia-rs>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from kornia>=0.7.3->torchgeo) (0.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia>=0.7.3->torchgeo) (24.1)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (1.3.2)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (0.0.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.32.3)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (4.66.5)
# Requirement already satisfied: pydantic>=1.10.5 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.8.2)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.4.0)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.0.7)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (3.1.15)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.11.7)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (4.12.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.43.3)
# Requirement already satisfied: jsonargparse<5.0,>=4.27.7 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (4.32.1)
# Requirement already satisfied: omegaconf<3.0,>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.3.0)
# Requirement already satisfied: rich<14.0,>=12.3.0 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (13.8.0)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in /usr/local/lib/python3.10/dist-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.6.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->torchgeo) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->torchgeo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->torchgeo) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->torchgeo) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->torchgeo) (3.1.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.3->torchgeo) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.3->torchgeo) (2024.1)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->torchgeo) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->torchgeo) (1.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio>=1.3->torchgeo) (71.0.4)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24.6 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.24.6)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch>=0.2->torchgeo) (0.7.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.4.12->torchgeo) (0.4.4)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch>=0.2->torchgeo) (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->torchgeo) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->torchgeo) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->torchgeo) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->torchgeo) (3.1.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (3.10.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo) (4.9.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.7.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.5->lightly!=1.4.26,>=1.4.5->torchgeo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.5->lightly!=1.4.26,>=1.4.5->torchgeo) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly!=1.4.26,>=1.4.5->torchgeo) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly!=1.4.26,>=1.4.5->torchgeo) (3.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.16.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX<3.0,>=2.2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->torchgeo) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->torchgeo) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning!=2.3.*,>=2->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (4.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo) (6.4.4)

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchgeo.datasets import EuroSAT100
import torch.nn.functional as F

# %%
'''training_data =sets.FashionMNIST(
      root="data",
      train=True,
      download=True,
      transform=ToTensor(),
)'''
# Out:
# 'training_data =sets.FashionMNIST(\n      root="data",\n      train=True,\n      download=True,\n      transform=ToTensor(),\n)'

# %%
training_data=EuroSAT100(
      root="data",
      split="train",
      download=True
)
# Out:
# Downloading https://cdn-lfs.huggingface.co/repos/fc/1d/fc1dee780dee1dae2ad48856d0961ac6aa5dfcaaaa4fb3561be4aedf19b7ccc7/2ed4bb4a6808004c98691f64b366827f7783c76a49151e7c2b70423eb77a5b76?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27EuroSAT100.zip%3B+filename%3D%22EuroSAT100.zip%22%3B&response-content-type=application%2Fzip&Expires=1725628054&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=gpG-4zJ8vnH61kOYM3j2omY7Cn65cHbGzntodWt939RbpJ4MDjRBSMlTRpsUu9BAwiYxPxlRmtpG8W%7EC8Kllv9spPTkdY%7EXT9pg5k1o42%7EJRdtqyy2YuYPMOi1EwBDYtOpCu5BLhUbBmqL0UGRjS9RJ-TYrbapxnavFKtF8DliNWaGVIyndJz4gPpVqpBfhvgy1LFJlGW7YhT7RFIKtbMxzFHU2EcUCxUPzp28S0Y%7Ey0pVvjYq6rxQJLeRKvMjscRmW8U-YFsYHkpXOSkSognXN2QYoGkxdVPaapK1sTe4OQxDTPhOmQTQ1-Bh1HPEqK2wQEZIznltiPa7oi853b8Q__&Key-Pair-Id=K3ESJI6DHPFC7 to data/EuroSAT100.zip
# 100%|██████████| 7717354/7717354 [00:00<00:00, 31256871.77it/s]
# Downloading https://huggingface.co/datasets/torchgeo/eurosat/resolve/06fd1b090bceecc0ce724cd21578ba7a6664fe8d/eurosat-train.txt to data/eurosat-train.txt
# 100%|██████████| 1152/1152 [00:00<00:00, 1565728.52it/s]
# Downloading https://huggingface.co/datasets/torchgeo/eurosat/resolve/06fd1b090bceecc0ce724cd21578ba7a6664fe8d/eurosat-val.txt to data/eurosat-val.txt
# 100%|██████████| 383/383 [00:00<00:00, 381390.89it/s]
# Downloading https://huggingface.co/datasets/torchgeo/eurosat/resolve/06fd1b090bceecc0ce724cd21578ba7a6664fe8d/eurosat-test.txt to data/eurosat-test.txt
# 100%|██████████| 382/382 [00:00<00:00, 387572.36it/s]

# %%
test_data=EuroSAT100(
      root="data",
      split="val",
      download=True,
)

# %%
# maps tensor from image to its textual reprensentation
labels_map = {
      0:"Annual Crop",
      1:"Forest",
      2:"Herbaceous Buildings",
      3:"Highway",
      4:"Industrial Buildings",
      5:"Pasture",
      6:"Permanent Crop",
      7:"Residential Buildings",
      8:"River",
      9:"Sea & Lake"
}

# %%
training_data[0]['image'].shape
# Out:
# torch.Size([13, 64, 64])

# %%
len(training_data)
# Out:
# 60

# %%
import matplotlib.pyplot as plt

# %%
figure = plt.figure(figsize=(8,8))
cols , rows = 3,3
for i in range(1,cols*rows+1):
  sample_idx = torch.randint(len(training_data),size=(1,)).item()
  data = training_data[sample_idx]
  img, label = data['image'],data['label'].item()
  figure.add_subplot(rows,cols,i)
  plt.title(labels_map[label])
  plt.axis('off')
  plt.imshow(img[3],cmap="gray")
plt.show()

# %%
# image in fcc(false composite)
figure = plt.figure(figsize=(8,8))
cols , rows = 3,3
for i in range(1,cols*rows+1):
  sample_idx = torch.randint(len(training_data),size=(1,)).item()
  data = training_data[sample_idx]
  img, label = data['image'],data['label'].item()
  img = torch.stack((img[7], img[3], img[2]), dim=0)
  img = torch.permute(img,(1,2,0))
  # img =T.TopILImage()(img)

  figure.add_subplot(rows,cols,i)
  plt.title(labels_map[label])
  plt.axis('off')
  # print(img)
  plt.imshow(img/10000.)
plt.show()

# %%
batch_size =4

#create data loaders
train_dataloader = DataLoader(training_data,batch_size=batch_size,shuffle=True)
test_dataloader = DataLoader(test_data,batch_size=batch_size,shuffle=True)

for data in test_dataloader:
     X=data['image']
     y=data['label']
     print(f"shape of X[N,C,H,W]:{X.shape}")
     print(f"shape of y:{y.shape} {y.dtype}")
     break
# Out:
# shape of X[N,C,H,W]:torch.Size([4, 13, 64, 64])
# shape of y:torch.Size([4]) torch.int64

# %%
device =  (
    "cuda"
    if torch.cuda.is_available()
    else"mps"
    if torch.backends.mps.is_available()
    else"cpu"

)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
     def _init_(self):
          super()._init_()
          self.flatten = nn.Flatten()
          self.linear_relu_stack= nn.Sequential(
              nn.linear(13*64*64,512),
              nn.ReLU(),
              nn.Linear(512,128),
              nn.ReLU(),
              nn.linear(128,32),
              nn.ReLU(),
              nn.Linear(32,10)
              )

     def forward(self,x):
          x=self.flatten(x)
          logits=self.linear_relu_stack(x)
          return logits

# %%
model =NeuralNetwork().to(device)

# %%
print(model)
# Out:
# NeuralNetwork()

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr=1e-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ccefbb114e29> in <cell line: 2>()
#       1 loss_fn = nn.CrossEntropyLoss()
# ----> 2 optimizer = torch.optim.SGD(model.parameters(),lr=1e-4)
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/sgd.py in __init__(self, params, lr, momentum, dampening, weight_decay, nesterov, maximize, foreach, differentiable, fused)
#      54         if nesterov and (momentum <= 0 or dampening != 0):
#      55             raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# ---> 56         super().__init__(params, defaults)
#      57
#      58         if fused:
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in __init__(self, params, defaults)
#     360         param_groups = list(params)
#     361         if len(param_groups) == 0:
# --> 362             raise ValueError("optimizer got an empty parameter list")
#     363         if not isinstance(param_groups[0], dict):
#     364             param_groups = [{"params": param_groups}]
#
# ValueError: optimizer got an empty parameter list
